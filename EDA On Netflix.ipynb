# %% [markdown]
# # Project: Exploratory Data Analysis (EDA) on Netflix Titles #

# %% [markdown]
# ![BrandAssets_Logos_01-Wordmark.jpg](attachment:0f0225fc-4a59-484e-9ee7-8d72df68de8c.jpg)

# %% [markdown]
# # Introduction:
# ### I worked on an Exploratory Data Analysis (EDA) project using a Netflix dataset, which includes information about movies and TV shows available on Netflix. The dataset consists of attributes like title, type, director, cast, country, release year, rating, and genres.

# %% [markdown]
# # Objective:
# ## The goal of this project is to analyze the Netflix dataset to uncover patterns, trends, and insights about the platform’s content. This includes understanding content distribution, genre popularity, and release trends.

# %% [markdown]
# ## Attributes of this dataset
# * title
# * type
# * director
# * cast
# * country
# * release year
# * rating
# * genres

# %% [markdown]
# # Import the all libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Loading The datatset in the form of pandas dataframe

# %%
data = pd.read_csv("netflix_titles.csv")
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %% [markdown]
# # Getting Some Basic Information about the dataset.

# %% [markdown]
# ## Show top 5 records of the dataset.

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %% [markdown]
# ##  Show bottom 5 records of the dataset.

# %%
data.tail()
# Out:
#        show_id     type                                        title director  \
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 6231                                                NaN             NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#      date_added  release_year rating    duration  \
# ...

# %% [markdown]
# ## Show the No. of rows and columns in the dataset.

# %%
data.shape
# Out:
# (6234, 12)

# %% [markdown]
# # Show each columns of the dataset

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ## Show the datatypes of each columns

# %%
data.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ## Show index, columns, data types of each columns , memory at once

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %% [markdown]
# ## Show all the statistical function, we use :

# %%
data.describe()
# Out:
#             show_id  release_year
# count  6.234000e+03    6234.00000
# mean   7.670368e+07    2013.35932
# std    1.094296e+07       8.81162
# min    2.477470e+05    1925.00000
# 25%    8.003580e+07    2013.00000
# 50%    8.016337e+07    2016.00000
# 75%    8.024489e+07    2018.00000
# max    8.123573e+07    2020.00000

# %% [markdown]
# # Task 1 : is there any duplicate records int the dataset

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.shape
# Out:
# (6234, 12)

# %% [markdown]
# # to check the row wise and detect the duplicate rows

# %% [markdown]
# # use duplicated

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6229    False
# 6230    False
# 6231    False
# 6232    False
# 6233    False
# Length: 6234, dtype: bool

# %% [markdown]
# # If we see the data in the form of dataframe we put the query in the dataset name .

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# # Task 2 : Is there any null values present in any columns ? Sow with heatmap

# %% [markdown]
# ### is null function. : we get the result in the form of boolean formate like TRUE and FALSE.

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False      True  False    False       False
# 3       False  False  False      True  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 6229    False  False  False      True  False    False        True
# 6230    False  False  False      True  False    False        True
# 6231    False  False  False      True   True     True        True
# 6232    False  False  False      True  False    False        True
# 6233    False  False  False      True  False    False        True
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %% [markdown]
# # we want to check how many null values are present in each column.

# %% [markdown]
# ## we use isnull function with sum function

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Null values shown by heatmap

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Q1 : For "House of cards" , what is the show id and who is the director of this show ?

# %% [markdown]
# # isin Function

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %% [markdown]
# # To show all records of a particular item in any column.

# %%
data[data['title'].isin(['House of Cards'])]
# Out:
#        show_id     type           title director  \
# 5741  70178217  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 5741  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#              date_added  release_year rating   duration  \
# 5741   November 2, 2018          2018  TV-MA  6 Seasons
#
#                     listed_in  \
# 5741  TV Dramas, TV Thrillers
#
#                                             description
# 5741  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Str.contains()

# %% [markdown]
# # To show all records of a particular string in any column.

# %%
data['title'].str.contains('House of Cards') # it will show the record in the form of boolean formate
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6229    False
# 6230    False
# 6231    False
# 6232    False
# 6233    False
# Name: title, Length: 6234, dtype: bool

# %% [markdown]
# data[data['title'].str.contains('House of Cards')]

# %% [markdown]
# # Q2 : In which year highest no. of TV Shows and movies were released .

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %% [markdown]
# # dtypes

# %%
data.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # to_datetime

# %%
data['Date_N'] = pd.to_datetime(data['release_year'])
data.Date_N
# Out:
# 0      1970-01-01 00:00:00.000002019
# 1      1970-01-01 00:00:00.000002016
# 2      1970-01-01 00:00:00.000002013
# 3      1970-01-01 00:00:00.000002016
# 4      1970-01-01 00:00:00.000002017
#                     ...
# 6229   1970-01-01 00:00:00.000002015
# 6230   1970-01-01 00:00:00.000002016
# 6231   1970-01-01 00:00:00.000002016
# 6232   1970-01-01 00:00:00.000002013
# 6233   1970-01-01 00:00:00.000002003
# Name: Date_N, Length: 6234, dtype: datetime64[ns]

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
# if we want to check the datatypes of this column we can use 'dtypes'
data.dtypes
# Out:
# show_id                  int64
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %% [markdown]
# # dt.year.Value Counts Function

# %% [markdown]
# ### It counts the occurences of all individual year on date column

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 1970    6234
# Name: count, dtype: int64

# %% [markdown]
# # Q3 How many movies and tv shown are in the dataset

# %% [markdown]
# ### groupby ()

# %%
data.head(3)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
#
#      rating  duration                           listed_in  \
# ...

# %% [markdown]
# # To group all unique items of a column and shown their count

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %% [markdown]
# # Countplot()

# %% [markdown]
# ## To show the count of all unique values of any column in the form of bar graph.

# %%
sns.countplot(data['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %% [markdown]
# # Q4 : Show all the Movies that were released in year 1970

# %%
data.head(4)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# ...

# %% [markdown]
# # To create new year column ; it will consider only year

# %%
data['year'] = data['Date_N'].dt.year
data.year
# Out:
# 0       1970
# 1       1970
# 2       1970
# 3       1970
# 4       1970
#         ...
# 6229    1970
# 6230    1970
# 6231    1970
# 6232    1970
# 6233    1970
# Name: year, Length: 6234, dtype: int32

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %% [markdown]
# ## Filtering

# %%
data[(data['type'] == 'Movie') & (data['year'] == 1970)]
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     80117401  Movie               Jandino: Whatever it Takes
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...        ...    ...                                      ...
# 5577  80085438  Movie                          Frank and Cindy
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
# 6231  80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# ...

# %% [markdown]
# # Q5 : Show only the Titles of all TV Shows that were released in India only.

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %% [markdown]
# ### Filtering

# %%
data[(data['type'] == 'TV Show') & (data['country'] == 'India')] ['title']
# Out:
# 99                                Bard of Blood
# 648                 Mighty Little Bheem: Diwali
# 689               Devlok with Devdutt Pattanaik
# 789                             College Romance
# 793                           Engineering Girls
# 797                                Girls Hostel
# 804                                     Inmates
# 1653                                  Thackeray
# 1762                            Classic Legends
# 1838                Anjaan: Special Crimes Unit
# 1850                   Khan: No. 1 Crime Hunter
# 1998      Th Eena Meena Deeka Chase Comedy Show
# 2090                                Delhi Crime
# 2200                              Khotey Sikkey
# 2210                                 Rishta.com
# 2297              Cricket Fever: Mumbai Indians
# 2333                       Darr Sabko Lagta Hai
# 2359                                   Mahi Way
# 2661                                      Leila
# 2718                  Gabru: Hip Hop Revolution
# ...

# %% [markdown]
# # Q6 : Show top 10 directors who gave the highest number of TV Shows and Movies to Netflix

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %% [markdown]
# ### Value_Counts

# %%
data['director'].value_counts().head(10)
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              14
# Jay Karas                 13
# Jay Chapman               12
# Steven Spielberg           9
# Martin Scorsese            9
# Lance Bangs                8
# David Dhawan               8
# Johnnie To                 8
# Shannon Hartman            7
# Name: count, dtype: int64

# %% [markdown]
# # Q7 : IN how many movies / shows ,Tom cruise was cast?

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %% [markdown]
# ### Filtering

# %%
data[data['cast'] == 'Tom Cruise' ]  # no ine data is here which are related with tom cruiser
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, year]
# Index: []

# %% [markdown]
# ### str.contains()

# %%
data['cast'].str.contains('Tom Cruise')  # it contains the null values .
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6229    False
# 6230    False
# 6231      NaN
# 6232    False
# 6233    False
# Name: cast, Length: 6234, dtype: object

# %% [markdown]
# # Creating a new dataframe

# %% [markdown]
# ## It drops the rows that contains all or any missing values

# %% [markdown]
# ### We use dropna function

# %%
data_new = data.dropna()
data_new.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 4                             United States  September 8, 2017          2017
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 4  TV-14   99 min                            Comedies
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#        show_id   type     title              director  \
# 3071  60029369  Movie  Rain Man        Barry Levinson
# 3538  60000440  Movie  Magnolia  Paul Thomas Anderson
#
#                                                    cast        country  \
# 3071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
# 3538  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
#
#            date_added  release_year rating duration  \
# 3071     July 1, 2019          1988      R  134 min
# 3538  January 1, 2020          1999      R  189 min
#
#                        listed_in  \
# 3071      Classic Movies, Dramas
# 3538  Dramas, Independent Movies
#
#                                             description  \
# 3071  A fast-talking yuppie is forced to slow down w...
# 3538  Through chance, human action, past history and...
#
#                             Date_N  year
# 3071 1970-01-01 00:00:00.000001988  1970
# 3538 1970-01-01 00:00:00.000001999  1970

# %% [markdown]
# # Q 8 : What are the different Ratings defined by Netflix ?

# %%
data_new.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 4                             United States  September 8, 2017          2017
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 4  TV-14   99 min                            Comedies
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %% [markdown]
# ### nunique()

# %%
data['rating'].nunique()
# Out:
# 14

# %% [markdown]
# # If we want to see all the different ratings

# %% [markdown]
# ### We use unique function

# %%
data['rating'].unique()
# Out:
# array(['TV-PG', 'TV-MA', 'TV-Y7-FV', 'TV-Y7', 'TV-14', 'R', 'TV-Y', 'NR',
#        'PG-13', 'TV-G', 'PG', 'G', nan, 'UR', 'NC-17'], dtype=object)

# %% [markdown]
# # Q 9 : How many TV show got  the 'TV-14' rating in Canada?

# %%
data.head(3)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
#
#      rating  duration                           listed_in  \
# ...

# %%
data[(data['type'] == 'Movie') & (data['rating'] == 'TV-14')]
# Out:
#        show_id   type                          title          director  \
# 4     80125979  Movie                   #realityhigh  Fernando Lebrija
# 20    80060297  Movie              Manhattan Romance       Tom O'Brien
# 36    81113928  Movie          Care of Kancharapalem    Maha Venkatesh
# 37    81052275  Movie          Ee Nagaraniki Emaindi   Tharun Bhascker
# 38    81132437  Movie            Kill Me If You Dare      Şenol Sönmez
# ...        ...    ...                            ...               ...
# 5550  80131414  Movie                Born to Be Free  Gayane Petrosyan
# 5559  80081955  Movie           Five Nights in Maine      Maris Curran
# 5560  80164112  Movie  Joe Cocker: Mad Dog with Soul     John Edginton
# 5562  70302835  Movie                          Killa      Avinash Arun
# 5568  80158479  Movie                      Salaakhen         A. Salaam
#
#                                                    cast  \
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...

# %%
data[(data['type'] == 'Movie') & (data['rating'] == 'TV-14') & (data['country'] == 'Canada')]
# Out:
#        show_id   type                                              title  \
# 726   80990869  Movie        Martin Matte: La vie, la mort...eh la la..!
# 1324  80205085  Movie                                  Long Time Running
# 1900  80178720  Movie                                         Kiss & Cry
# 2620  81136963  Movie                               The Wrong Babysitter
# 2631  81123051  Movie                                  3 Seconds Divorce
# 2705  81070008  Movie  Prosecuting Evil: The Extraordinary World of B...
# 3083  81017506  Movie                        The Accountant of Auschwitz
# 3099  80997402  Movie                         Counterfeiting in Suburbia
# 3976  70137744  Movie                     Rush: Beyond the Lighted Stage
# 4332  81029400  Movie                                     At First Light
# 4692  80203787  Movie                                         Sardaar ji
# 4877  80163054  Movie                         Sadie's Last Days on Earth
# ...

# %% [markdown]
# ## We can fetch the count also by using the shape

# %%
data[(data['type'] == 'Movie') & (data['rating'] == 'TV-14')].shape
# Out:
# (1038, 14)

# %% [markdown]
# # Q 10; What is the maximum duration of a movie and show on netflix ?

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
data.duration.unique()
# Out:
# array(['90 min', '94 min', '1 Season', '99 min', '110 min', '60 min',
#        '78 min', '95 min', '58 min', '62 min', '65 min', '61 min',
#        '135 min', '98 min', '96 min', '79 min', '113 min', '80 min',
#        '77 min', '112 min', '106 min', '102 min', '114 min', '125 min',
#        '142 min', '133 min', '100 min', '86 min', '146 min', '10 min',
#        '122 min', '126 min', '116 min', '130 min', '70 min', '128 min',
#        '88 min', '108 min', '93 min', '64 min', '107 min', '92 min',
#        '111 min', '103 min', '40 min', '85 min', '72 min', '45 min',
#        '89 min', '24 min', '127 min', '163 min', '117 min', '42 min',
#        '104 min', '75 min', '82 min', '38 min', '97 min', '81 min',
#        '91 min', '152 min', '87 min', '121 min', '101 min', '119 min',
#        '83 min', '182 min', '124 min', '63 min', '139 min', '171 min',
#        '84 min', '69 min', '76 min', '41 min', '153 min', '141 min',
# ...

# %%
 data.duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ## str.split()

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
data[['Minute','Unit']] = data['duration'].str.split(' ',expand = True)

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %% [markdown]
# ## MAX()

# %%
data.Minute.max()
# Out:
# '99'

# %% [markdown]
# ## MIN

# %%
data.Minute.min()
# Out:
# '1'

# %% [markdown]
# # Q 11 : Which individual country has the highext no. of TV Shows?

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %% [markdown]
# ## I will ceate a new dataframe

# %%
data_tvshow = data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#     show_id     type                             title director  \
# 2  70234439  TV Show                Transformers Prime      NaN
# 3  80058654  TV Show  Transformers: Robots in Disguise      NaN
#
#                                                 cast        country  \
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...  United States
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...  United States
#
#           date_added  release_year    rating  duration listed_in  \
# 2  September 8, 2018          2013  TV-Y7-FV  1 Season  Kids' TV
# 3  September 8, 2018          2016     TV-Y7  1 Season  Kids' TV
#
#                                          description  \
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
#
#                          Date_N  year Minute    Unit
# 2 1970-01-01 00:00:00.000002013  1970      1  Season
# 3 1970-01-01 00:00:00.000002016  1970      1  Season

# %%
data_tvshow.country.value_counts()
# Out:
# country
# United States                                                  550
# United Kingdom                                                 178
# Japan                                                          129
# South Korea                                                    104
# Taiwan                                                          65
#                                                               ...
# United States, Chile                                             1
# France, United States, Canada                                    1
# United States, New Zealand, Japan                                1
# Italy, South Africa, West Germany, Australia, United States      1
# Cyprus, Austria, Thailand                                        1
# Name: count, Length: 154, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# country
# United States    550
# Name: count, dtype: int64

# %% [markdown]
# # Q 12 : How can we sort the dataset by release year column ?

# %% [markdown]
# ### By default in ascending order

# %%
data.sort_values(by = 'release_year').head(10)
# Out:
#        show_id     type                                             title  \
# 4292  81030762  TV Show                 Pioneers: First Women Filmmakers*
# 2011  60027945    Movie                                    Prelude to War
# 2013  60027942    Movie                              The Battle of Midway
# 2022  80119186    Movie     Undercover: How to Operate Behind Enemy Lines
# 2023  70013050    Movie                Why We Fight: The Battle of Russia
# 2026  70022548    Movie                   WWII: Report from the Aleutians
# 2017  80119194    Movie  The Memphis Belle: A Story of a\nFlying Fortress
# 2019  80119191    Movie                                 The Negro Soldier
# 2021  80119189    Movie                                  Tunisian Victory
# 2012  80119188    Movie                                        San Pietro
#
#                                                director  \
# 4292                                                NaN
# ...

# %% [markdown]
# ### If we want in descending order we use this:

# %%
data.sort_values(by = 'release_year', ascending = False).head(10)
# Out:
#        show_id     type                          title  \
# 3467  81011449  TV Show                 Medical Police
# 3249  81006825    Movie  All the Freckles in the World
# 3220  80997687  TV Show                        Dracula
# 3427  81060049    Movie     Leslie Jones: Time Machine
# 3436  80239306  TV Show     The Healing Powers of Dude
# 3195  80233408    Movie          Live Twice, Love Once
# 3189  81039393  TV Show                          Cheer
# 3464  80237329  TV Show               AJ and the Queen
# 3180  81214114    Movie                  Bulletproof 2
# 3466  81183491  TV Show   Jamtara - Sabka Number Ayega
#
#                        director  \
# 3467                        NaN
# 3249               Yibrán Asuad
# 3220                        NaN
# 3427  David Benioff, D.B. Weiss
# 3436                        NaN
# 3195               Maria Ripoll
# 3189                        NaN
# 3464                        NaN
# 3180           Don Michael Paul
# ...

# %% [markdown]
# # Insights and Conclusion:
# ### "Some key insights from the analysis included:"
#
# ### Netflix has more movies than TV shows.
# ### There has been a rise in content production in recent years.
# ### The USA contributes the most content, followed by India.
# ### 'TV-MA' and 'TV-14' are the most common ratings, indicating a focus on mature audiences.
